# %%
import pandas as pd
import json
import math

def get_pythagoras(x, y):
    return math.sqrt(x ** 2 + y ** 2)

with open("ColdWeather.dat") as json_data:
    data = json.load(json_data)
full_dataset = pd.DataFrame(data['_notes'])
full_dataset['_yCenter'] = full_dataset.loc[:, ('_lineLayer')].apply(lambda x: 1 + x * 0.55)
full_dataset['_xCenter'] = full_dataset.loc[:, ('_lineIndex')].apply(lambda x: -0.9 + x * 0.6)
left = (full_dataset[full_dataset['_type'] == 0]) #All left handed notes
right = (full_dataset[full_dataset['_type'] == 1]) #All right handed notes

left['_xMovement'] = left.loc[:, ['_xCenter']].diff().fillna(0)
left['_yMovement'] = left.loc[:, ['_yCenter']].diff().fillna(0)
left['_totMovement'] = left.apply(lambda x: get_pythagoras(x['_xMovement'], x['_yMovement']), axis=1).fillna(0) 
left['_angleChange'] = left.apply(lambda x: math.atan(x['_yMovement']/x['_xMovement']), axis=1)

right['_xMovement'] = right.loc[:, ['_xCenter']].diff().fillna(0)
right['_yMovement'] = right.loc[:, ['_yCenter']].diff().fillna(0)
right['_totMovement'] = right.apply(lambda x: get_pythagoras(x['_xMovement'], x['_yMovement']), axis=1).fillna(0)
right['_angleChange'] = right.apply(lambda x: math.atan(x['_yMovement']/x['_xMovement']), axis=1)


average_angle = (left['_angleChange'].mean() + right['_angleChange'].mean()) / 2
time = (full_dataset['_time'].max() - full_dataset['_time'].min())
total_distance= (left['_totMovement'].sum() + right['_totMovement'].sum()) / 2
average_speed = total_distance/time


complexity_speed= average_speed/2
complexity_angle= average_angle/30

complexity = complexity_angle + complexity_speed

print(complexity)
# Out:
# 0.7481375749259609
# C:\Users\Matteo\AppData\Local\Temp/ipykernel_12460/2803238547.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   left['_xMovement'] = left.loc[:, ['_xCenter']].diff().fillna(0)
# C:\Users\Matteo\AppData\Local\Temp/ipykernel_12460/2803238547.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   left['_yMovement'] = left.loc[:, ['_yCenter']].diff().fillna(0)
# C:\Users\Matteo\AppData\Local\Temp/ipykernel_12460/2803238547.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   left['_totMovement'] = left.apply(lambda x: get_pythagoras(x['_xMovement'], x['_yMovement']), axis=1).fillna(0)
# C:\Users\Matteo\AppData\Local\Temp/ipykernel_12460/2803238547.py:19: RuntimeWarning: invalid value encountered in double_scalars
#   left['_angleChange'] = left.apply(lambda x: math.atan(x['_yMovement']/x['_xMovement']), axis=1)
# C:\Users\Matteo\AppData\Local\Temp/ipykernel_12460/2803238547.py:19: RuntimeWarning: divide by zero encountered in double_scalars
#   left['_angleChange'] = left.apply(lambda x: math.atan(x['_yMovement']/x['_xMovement']), axis=1)
# C:\Users\Matteo\AppData\Local\Temp/ipykernel_12460/2803238547.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   left['_angleChange'] = left.apply(lambda x: math.atan(x['_yMovement']/x['_xMovement']), axis=1)
# C:\Users\Matteo\AppData\Local\Temp/ipykernel_12460/2803238547.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   right['_xMovement'] = right.loc[:, ['_xCenter']].diff().fillna(0)
# C:\Users\Matteo\AppData\Local\Temp/ipykernel_12460/2803238547.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   right['_yMovement'] = right.loc[:, ['_yCenter']].diff().fillna(0)
# C:\Users\Matteo\AppData\Local\Temp/ipykernel_12460/2803238547.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   right['_totMovement'] = right.apply(lambda x: get_pythagoras(x['_xMovement'], x['_yMovement']), axis=1).fillna(0)
# C:\Users\Matteo\AppData\Local\Temp/ipykernel_12460/2803238547.py:24: RuntimeWarning: invalid value encountered in double_scalars
#   right['_angleChange'] = right.apply(lambda x: math.atan(x['_yMovement']/x['_xMovement']), axis=1)
# C:\Users\Matteo\AppData\Local\Temp/ipykernel_12460/2803238547.py:24: RuntimeWarning: divide by zero encountered in double_scalars
#   right['_angleChange'] = right.apply(lambda x: math.atan(x['_yMovement']/x['_xMovement']), axis=1)
# C:\Users\Matteo\AppData\Local\Temp/ipykernel_12460/2803238547.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   right['_angleChange'] = right.apply(lambda x: math.atan(x['_yMovement']/x['_xMovement']), axis=1)
